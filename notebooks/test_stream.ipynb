# %%
import os
os.environ['S3_ENDPOINT_URL'] = 'http://204.168.238.119:9000'
os.environ['AWS_ACCESS_KEY_ID'] = 'leviathan'
os.environ['AWS_SECRET_ACCESS_KEY'] = 'Leviathan!Rises13'

from RayNet.streaming import create_streaming_dataloaders

train_loader, val_loader = create_streaming_dataloaders(
    remote_train='s3://gazegene/train',
    remote_val='s3://gazegene/val',
    batch_size=12,
    num_workers=1,
)
